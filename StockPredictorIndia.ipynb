# %%
import yfinance as yf
import pandas as pd
import numpy as np
nifty50 = yf.Ticker("^NSEI")

nifty50 = nifty50.history(period = 'max')
nifty50
# Out:
#                                    Open          High           Low  \
# Date
# 2007-09-17 00:00:00+05:30   4518.450195   4549.049805   4482.850098
# 2007-09-18 00:00:00+05:30   4494.100098   4551.799805   4481.549805
# 2007-09-19 00:00:00+05:30   4550.250000   4739.000000   4550.250000
# 2007-09-20 00:00:00+05:30   4734.850098   4760.850098   4721.149902
# 2007-09-21 00:00:00+05:30   4752.950195   4855.700195   4733.700195
# ...                                 ...           ...           ...
# 2024-07-10 00:00:00+05:30  24459.849609  24461.050781  24141.800781
# 2024-07-11 00:00:00+05:30  24396.550781  24402.650391  24193.750000
# 2024-07-12 00:00:00+05:30  24387.949219  24592.199219  24331.150391
# 2024-07-15 00:00:00+05:30  24587.599609  24635.050781  24522.750000
# 2024-07-16 00:00:00+05:30  24615.900391  24661.250000  24587.650391
#
#                                   Close  Volume  Dividends  Stock Splits
# Date
# 2007-09-17 00:00:00+05:30   4494.649902       0        0.0           0.0
# 2007-09-18 00:00:00+05:30   4546.200195       0        0.0           0.0
# 2007-09-19 00:00:00+05:30   4732.350098       0        0.0           0.0
# 2007-09-20 00:00:00+05:30   4747.549805       0        0.0           0.0
# 2007-09-21 00:00:00+05:30   4837.549805       0        0.0           0.0
# ...                                 ...     ...        ...           ...
# 2024-07-10 00:00:00+05:30  24324.449219  292300        0.0           0.0
# 2024-07-11 00:00:00+05:30  24315.949219  306400        0.0           0.0
# 2024-07-12 00:00:00+05:30  24502.150391  325800        0.0           0.0
# 2024-07-15 00:00:00+05:30  24586.699219  305400        0.0           0.0
# 2024-07-16 00:00:00+05:30  24613.000000  283200        0.0           0.0
#
# [4124 rows x 7 columns]

# %% [markdown]
# # Data cleaning and Visualization

# %%
nifty50.plot.line(y='Close' , use_index = 'True')
# Out:
# <Axes: xlabel='Date'>

# %%
del nifty50['Dividends']
del nifty50['Stock Splits']

# %%
nifty50['Tomorrow'] = nifty50['Close'].shift(-1)
nifty50
# Out:
#                                    Open          High           Low  \
# Date
# 2007-09-17 00:00:00+05:30   4518.450195   4549.049805   4482.850098
# 2007-09-18 00:00:00+05:30   4494.100098   4551.799805   4481.549805
# 2007-09-19 00:00:00+05:30   4550.250000   4739.000000   4550.250000
# 2007-09-20 00:00:00+05:30   4734.850098   4760.850098   4721.149902
# 2007-09-21 00:00:00+05:30   4752.950195   4855.700195   4733.700195
# ...                                 ...           ...           ...
# 2024-07-10 00:00:00+05:30  24459.849609  24461.050781  24141.800781
# 2024-07-11 00:00:00+05:30  24396.550781  24402.650391  24193.750000
# 2024-07-12 00:00:00+05:30  24387.949219  24592.199219  24331.150391
# 2024-07-15 00:00:00+05:30  24587.599609  24635.050781  24522.750000
# 2024-07-16 00:00:00+05:30  24615.900391  24661.250000  24587.650391
#
#                                   Close  Volume      Tomorrow
# Date
# 2007-09-17 00:00:00+05:30   4494.649902       0   4546.200195
# 2007-09-18 00:00:00+05:30   4546.200195       0   4732.350098
# 2007-09-19 00:00:00+05:30   4732.350098       0   4747.549805
# 2007-09-20 00:00:00+05:30   4747.549805       0   4837.549805
# 2007-09-21 00:00:00+05:30   4837.549805       0   4932.200195
# ...                                 ...     ...           ...
# 2024-07-10 00:00:00+05:30  24324.449219  292300  24315.949219
# 2024-07-11 00:00:00+05:30  24315.949219  306400  24502.150391
# 2024-07-12 00:00:00+05:30  24502.150391  325800  24586.699219
# 2024-07-15 00:00:00+05:30  24586.699219  305400  24613.000000
# 2024-07-16 00:00:00+05:30  24613.000000  283200           NaN
#
# [4124 rows x 6 columns]

# %%
nifty50['Target'] = (nifty50['Tomorrow'] > nifty50['Close']).astype(int)

# %%
nifty50 = nifty50.loc['2008-01-01':].copy()
nifty50
# Out:
#                                    Open          High           Low  \
# Date
# 2011-01-03 00:00:00+05:30   6177.450195   6178.549805   6147.200195
# 2011-01-04 00:00:00+05:30   6172.750000   6181.049805   6124.399902
# 2011-01-05 00:00:00+05:30   6141.350098   6141.350098   6062.350098
# 2011-01-06 00:00:00+05:30   6107.000000   6116.149902   6022.299805
# 2011-01-07 00:00:00+05:30   6030.899902   6051.200195   5883.600098
# ...                                 ...           ...           ...
# 2024-07-10 00:00:00+05:30  24459.849609  24461.050781  24141.800781
# 2024-07-11 00:00:00+05:30  24396.550781  24402.650391  24193.750000
# 2024-07-12 00:00:00+05:30  24387.949219  24592.199219  24331.150391
# 2024-07-15 00:00:00+05:30  24587.599609  24635.050781  24522.750000
# 2024-07-16 00:00:00+05:30  24615.900391  24661.250000  24587.650391
#
#                                   Close  Volume      Tomorrow  Target
# Date
# 2011-01-03 00:00:00+05:30   6157.600098       0   6146.350098       0
# 2011-01-04 00:00:00+05:30   6146.350098       0   6079.799805       0
# 2011-01-05 00:00:00+05:30   6079.799805       0   6048.250000       0
# 2011-01-06 00:00:00+05:30   6048.250000       0   5904.600098       0
# 2011-01-07 00:00:00+05:30   5904.600098       0   5762.850098       0
# ...                                 ...     ...           ...     ...
# 2024-07-10 00:00:00+05:30  24324.449219  292300  24315.949219       0
# 2024-07-11 00:00:00+05:30  24315.949219  306400  24502.150391       1
# 2024-07-12 00:00:00+05:30  24502.150391  325800  24586.699219       1
# 2024-07-15 00:00:00+05:30  24586.699219  305400  24613.000000       1
# 2024-07-16 00:00:00+05:30  24613.000000  283200           NaN       0
#
# [3316 rows x 7 columns]

# %%
nifty50['Target'].value_counts()
# Out:
# Target
# 1    1773
# 0    1543
# Name: count, dtype: int64

# %% [markdown]
# Training Model

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=100 , min_samples_split=100 , random_state=1)

train =nifty50.iloc[:-50]
test = nifty50.iloc[-50:]

predictors = ['Close' , 'Volume' , 'Open' , 'High', 'Low']
model.fit(train[predictors], train['Target'])
# Out:
# RandomForestClassifier(min_samples_split=100, random_state=1)

# %%
from sklearn.metrics import precision_score
preds = model.predict(test[predictors])
preds = pd.Series(preds , index=test.index)

# %%
prec_score = precision_score (test['Target'],preds)
prec_score
# Out:
# 0.6363636363636364

# %%
combined = pd.concat([test['Target'] , preds] , axis=1)
combined.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
def predict(train , test , predictors , model) : 
    model.fit(train[predictors] , train['Target'])
    preds = model.predict(test[predictors]) 
    preds = pd.Series(preds, index=test.index, name="Predictions")
    combined = pd.concat([test["Target"], preds], axis=1)
    return combined

# %%
def backtest(data, model, predictors, start=2500, step=250):
    all_predictions = []

    for i in range(start, data.shape[0], step):
        train = data.iloc[0:i].copy()
        test = data.iloc[i:(i+step)].copy()
        predictions = predict(train, test, predictors, model)
        all_predictions.append(predictions)
    
    return pd.concat(all_predictions)

# %%
predictions = backtest(nifty50, model, predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 0    646
# 1    170
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.5352941176470588

# %%
predictions["Target"].value_counts() / predictions.shape[0]
# Out:
# Target
# 1    0.555147
# 0    0.444853
# Name: count, dtype: float64

# %%
predictions
# Out:
#                            Target  Predictions
# Date
# 2021-03-25 00:00:00+05:30       1            1
# 2021-03-26 00:00:00+05:30       1            1
# 2021-03-30 00:00:00+05:30       0            1
# 2021-03-31 00:00:00+05:30       1            1
# 2021-04-01 00:00:00+05:30       0            1
# ...                           ...          ...
# 2024-07-10 00:00:00+05:30       0            0
# 2024-07-11 00:00:00+05:30       1            0
# 2024-07-12 00:00:00+05:30       1            0
# 2024-07-15 00:00:00+05:30       1            0
# 2024-07-16 00:00:00+05:30       0            0
#
# [816 rows x 2 columns]
